# %%
#Módulos utilizados
import pandas as pd
from datetime import date
import csv
from bs4 import BeautifulSoup
import requests

# %%
#criando as variáveis do dia de hoje
todays_date = date.today()

todays_year = todays_date.year
todays_year_str = str(todays_year)

todays_month = todays_date.month

# %%
#Função que obtém um dataframe de terceirizados de uma página html passada como argumento
def obtem_data_frame_terceirizados(site):
    #Entrar no [site] que contém a tabela de terceirizados
    #Carregar a tabela de terceirizados do site para um dataframe
    
    #Carrega uma lista de dataframes. Cada dataframe desta lista é uma tabela do site
    dfs_terceirizados = pd.read_html(site)
    
    #Obter somente o dataframe de terceirizados
    df_terceirizados = dfs_terceirizados[0]
    
    return df_terceirizados


def conta_quantidade_terceirizados(dataframe):
    #Contar e retornar a quantidade de linhas de um [dataframe] de terceirizados
    return len(dataframe.index)

def filtra_dataframe(dataframe: 'dataframe', nome_col: 'str', lista_valores: 'list'):
    #Filtrar um [dataframe] no [campo 'empresa'], com o valor da [empresa escolhida], aplicando
    df_filtrado = dataframe.loc[dataframe[nome_col].isin(lista_valores)]
    return df_filtrado

# %%
#Variáveis de acesso
arquivo_atual = r'C:\Users\pteix\STJ- Superior Tribunal de Justiça\AGS Teams - Documentos\1. Drive H AGS\Assessoria\0 Dados\PLS\GRUPOEXEC\1. TEMAS\GE Rec Tecnol\04. Impressão\QtdTerceirizados.csv'

# %%
#Carregando dados do arquivo atual
df_atual = pd.read_csv(arquivo_atual)

#Converte a coluna de datas para o formato de data do pandas
df_atual['data'] = pd.to_datetime(df_atual['data'])

#display(df_atual)
#print(df_atual.info())
# Out:
#           data  terceirizados  terceirizados_limpeza
# 0   2014-01-01           1597                    175
# 1   2014-02-01           1597                    175
# 2   2014-03-01           1592                    171
# 3   2014-04-01           1583                    171
# 4   2014-05-01           1582                    168
# ..         ...            ...                    ...
# 104 2022-09-01           1724                    147
# 105 2022-10-01           1738                    148
# 106 2022-11-01           1738                    147
# 107 2022-12-01           1739                    147
# 108 2023-01-01           1738                    148
#
# [109 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   109 non-null    datetime64[ns]
#  1   terceirizados          109 non-null    int64
#  2   terceirizados_limpeza  109 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 2.7 KB
# None

# %%
#Obtendo a data mais recente
ultima_data = df_atual['data'].max()

#Calculando data de corte para execução do código
data_corte = ultima_data - pd.Timedelta(days=180)
ano_corte = data_corte.year
mes_corte = data_corte.month
data_corte = pd.Timestamp(year = ano_corte, month = mes_corte, day=1 )

#print(ultima_data)
#print(data_corte)
# Out:
# Data de corte é menor!
#           data  terceirizados  terceirizados_limpeza
# 102 2022-07-01           1733                    148

# %%
#Inicia dicionário de dataframes
print('iniciando o dicionario')
dfs_terceirizados = {}

#Loop do ano: de 2014 até o ano atual
print('definindo variável i do loop - ano')
for i in range(ano_corte,todays_year + 1):

    # Define a variável string do ano
    print('definindo variável i_str')
    i_str = str(i)
    print(i_str)
    
    
    #Loop do mês: do mês 1 ao mês 12
    print('Entrando no looping do mês - variável j')
    for j in range(1,13):

        #Constrói a data da iteração
        data_iteracao = pd.Timestamp(year = i, month = j, day= 1)
        
        #Se data da iteração for menor que a data de corte, passa para o próximo valor do iterador de mês
        if data_iteracao < data_corte:
            continue
        
        #testa se o mês da iteração ainda não ocorreu
        print('fazendo o teste do valor da variável j')
        if ((i == todays_year) and (j > todays_month - 1)):
            break #sai do loop da variável j, responsável pelo mês
        else:
            print('não se trata do mês atual. Definindo variável j_str')
            #Define a variável string do mês da iteração
            print('testando se j é menor que 10')
            if j<10:
                j_str = '0'+str(j)
            else:
                j_str = str(j)
        
        print('definindo a variável string do codigo html')
        # Define a variável string do codigo html
        html_str = i_str + j_str + '01.html'
        print(html_str)
        
        
        #Define a string chave do dicionário
        print('definindo a chave do dicionário')
        dic_chave = data_iteracao

        #Define a variavel da pagina html a ser lida
        print('define a variável da endereco a ser acessado')
        endereco = r'https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_' + html_str
        
        #print('tentando obter resposta do servidor')
        #response = requests.get(endereco)
        
        #Imprime informações da iteração:
        print('Iteração {}-{}'.format(i_str, j_str))
        print('Link: {}'.format(endereco))
        #print(response)
        
        #Obtém a tabela do site
        #soup = BeautifulSoup(response.text, 'html.parser')
        #table = soup.find('table')

        df = pd.read_html(endereco)[0]
        dfs_terceirizados[dic_chave] = df
        
        display(df)
# Out:
# iniciando o dicionario
# definindo variável i do loop - ano
# definindo variável i_str
# 2022
# Entrando no looping do mês - variável j
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20220701.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2022-07
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20220701.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# 2             Abrahão Lopes dos Santos (XXX.412.461-XX)
# 3              Acrisio Rocha Guimarães (XXX.258.061-XX)
# 4             Adailza Pereira de Sousa (XXX.021.721-XX)
# ...                                                 ...
# 1729            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1730  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1731             Zaira Soares da Silva (XXX.584.961-XX)
# 1732              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1733          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 2                         G I EMPRESA DE SEGURANCA LTDA  07.473.476/0001-99
# 3               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 4                             REAL JG FACILITIES EIRELI  08.247.960/0001-62
# ...                                                 ...                 ...
# 1729           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1730  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1731                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1732            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1733                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                          Técnico em Secretariado
# 2                                        Vigilante
# 3      Técnico em Estocagem e Movimentação de Bens
# 4                                       Cozinheira
# ...                                            ...
# 1729                        Auxiliar de Biblioteca
# 1730                                 Digitalizador
# 1731  Técnico Atendimento Suporte Presencial - ASP
# 1732            Produtor de Jornalismo, Rádio e TV
# 1733                                      pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                               Gabinete da Presidência
# 2     Seção de Segurança Interna, Perimetral e de Re...
# 3                       Seção de Controle do Patrimônio
# 4                       Seção de Copa - Serviços Gerais
# ...                                                 ...
# 1729                  Biblioteca Ministro Oscar Saraiva
# 1730     Seção de Digitalização de Petições e Processos
# 1731                    Coordenadoria de Relacionamento
# 1732                        Coordenadoria de TV e Rádio
# 1733          Coordenadoria de Engenharia e Arquitetura
#
# [1734 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20220801.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2022-08
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20220801.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# 2             Abrahão Lopes dos Santos (XXX.412.461-XX)
# 3              Acrisio Rocha Guimarães (XXX.258.061-XX)
# 4             Adailza Pereira de Sousa (XXX.021.721-XX)
# ...                                                 ...
# 1702            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1703  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1704             Zaira Soares da Silva (XXX.584.961-XX)
# 1705              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1706          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 2                         G I EMPRESA DE SEGURANCA LTDA  07.473.476/0001-99
# 3               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 4                             REAL JG FACILITIES EIRELI  08.247.960/0001-62
# ...                                                 ...                 ...
# 1702           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1703  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1704                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1705            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1706                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                          Técnico em Secretariado
# 2                                        Vigilante
# 3      Técnico em Estocagem e Movimentação de Bens
# 4                                       Cozinheira
# ...                                            ...
# 1702                        Auxiliar de Biblioteca
# 1703                                 Digitalizador
# 1704  Técnico Atendimento Suporte Presencial - ASP
# 1705            Produtor de Jornalismo, Rádio e TV
# 1706                                      pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                               Gabinete da Presidência
# 2     Seção de Segurança Interna, Perimetral e de Re...
# 3                       Seção de Controle do Patrimônio
# 4                       Seção de Copa - Serviços Gerais
# ...                                                 ...
# 1702                  Biblioteca Ministro Oscar Saraiva
# 1703     Seção de Digitalização de Petições e Processos
# 1704                    Coordenadoria de Relacionamento
# 1705                        Coordenadoria de TV e Rádio
# 1706          Coordenadoria de Engenharia e Arquitetura
#
# [1707 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20220901.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2022-09
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20220901.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# 2             Abrahão Lopes dos Santos (XXX.412.461-XX)
# 3              Acrisio Rocha Guimarães (XXX.258.061-XX)
# 4             Adailza Pereira de Sousa (XXX.021.721-XX)
# ...                                                 ...
# 1720            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1721  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1722             Zaira Soares da Silva (XXX.584.961-XX)
# 1723              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1724          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 2                         G I EMPRESA DE SEGURANCA LTDA  07.473.476/0001-99
# 3               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 4                             REAL JG FACILITIES EIRELI  08.247.960/0001-62
# ...                                                 ...                 ...
# 1720           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1721  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1722                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1723            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1724                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                          Técnico em Secretariado
# 2                                        Vigilante
# 3      Técnico em Estocagem e Movimentação de Bens
# 4                                       Cozinheira
# ...                                            ...
# 1720                        Auxiliar de Biblioteca
# 1721                                 Digitalizador
# 1722  Técnico Atendimento Suporte Presencial - ASP
# 1723            Produtor de Jornalismo, Rádio e TV
# 1724                                      pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                               Gabinete da Presidência
# 2     Seção de Segurança Interna, Perimetral e de Re...
# 3                       Seção de Controle do Patrimônio
# 4                       Seção de Copa - Serviços Gerais
# ...                                                 ...
# 1720                  Biblioteca Ministro Oscar Saraiva
# 1721     Seção de Digitalização de Petições e Processos
# 1722                    Coordenadoria de Relacionamento
# 1723                        Coordenadoria de TV e Rádio
# 1724          Coordenadoria de Engenharia e Arquitetura
#
# [1725 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20221001.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2022-10
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20221001.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1                                      (XXX.810.461-XX)
# 2        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# 3             Abrahão Lopes dos Santos (XXX.412.461-XX)
# 4              Acrisio Rocha Guimarães (XXX.258.061-XX)
# ...                                                 ...
# 1734            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1735  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1736             Zaira Soares da Silva (XXX.584.961-XX)
# 1737              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1738          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1                            ALPHA TERCEIRIZAÇÃO EIRELI  05.456.176/0001-76
# 2               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 3                         G I EMPRESA DE SEGURANCA LTDA  07.473.476/0001-99
# 4               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# ...                                                 ...                 ...
# 1734           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1735  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1736                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1737            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1738                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                                         Servente
# 2                          Técnico em Secretariado
# 3                                        Vigilante
# 4      Técnico em Estocagem e Movimentação de Bens
# ...                                            ...
# 1734                        Auxiliar de Biblioteca
# 1735                                 Digitalizador
# 1736  Técnico Atendimento Suporte Presencial - ASP
# 1737            Produtor de Jornalismo, Rádio e TV
# 1738                                      pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                        Seção de Limpeza e Conservação
# 2                               Gabinete da Presidência
# 3     Seção de Segurança Interna, Perimetral e de Re...
# 4                       Seção de Controle do Patrimônio
# ...                                                 ...
# 1734                  Biblioteca Ministro Oscar Saraiva
# 1735     Seção de Digitalização de Petições e Processos
# 1736                    Coordenadoria de Relacionamento
# 1737                        Coordenadoria de TV e Rádio
# 1738          Coordenadoria de Engenharia e Arquitetura
#
# [1739 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20221101.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2022-11
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20221101.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1                                      (XXX.810.461-XX)
# 2        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# 3             Abrahão Lopes dos Santos (XXX.412.461-XX)
# 4              Acrisio Rocha Guimarães (XXX.258.061-XX)
# ...                                                 ...
# 1734            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1735  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1736             Zaira Soares da Silva (XXX.584.961-XX)
# 1737              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1738          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1                            ALPHA TERCEIRIZAÇÃO EIRELI  05.456.176/0001-76
# 2               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 3                         G I EMPRESA DE SEGURANCA LTDA  07.473.476/0001-99
# 4               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# ...                                                 ...                 ...
# 1734           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1735  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1736                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1737            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1738                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                                         Servente
# 2                          Técnico em Secretariado
# 3                                        Vigilante
# 4      Técnico em Estocagem e Movimentação de Bens
# ...                                            ...
# 1734                        Auxiliar de Biblioteca
# 1735                                 Digitalizador
# 1736  Técnico Atendimento Suporte Presencial - ASP
# 1737            Produtor de Jornalismo, Rádio e TV
# 1738                                      Pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                        Seção de Limpeza e Conservação
# 2                               Gabinete da Presidência
# 3     Seção de Segurança Interna, Perimetral e de Re...
# 4                       Seção de Controle do Patrimônio
# ...                                                 ...
# 1734                  Biblioteca Ministro Oscar Saraiva
# 1735     Seção de Digitalização de Petições e Processos
# 1736                    Coordenadoria de Relacionamento
# 1737                        Coordenadoria de TV e Rádio
# 1738          Coordenadoria de Engenharia e Arquitetura
#
# [1739 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20221201.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2022-12
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20221201.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1                                      (XXX.810.461-XX)
# 2        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# 3             Abrahão Lopes dos Santos (XXX.412.461-XX)
# 4              Acrisio Rocha Guimarães (XXX.258.061-XX)
# ...                                                 ...
# 1735            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1736  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1737             Zaira Soares da Silva (XXX.584.961-XX)
# 1738              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1739          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1                            ALPHA TERCEIRIZAÇÃO EIRELI  05.456.176/0001-76
# 2               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# 3                         G I EMPRESA DE SEGURANCA LTDA  07.473.476/0001-99
# 4               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# ...                                                 ...                 ...
# 1735           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1736  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1737                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1738            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1739                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                                         Servente
# 2                          Técnico em Secretariado
# 3                                        Vigilante
# 4      Técnico em Estocagem e Movimentação de Bens
# ...                                            ...
# 1735                        Auxiliar de Biblioteca
# 1736                                 Digitalizador
# 1737  Técnico Atendimento Suporte Presencial - ASP
# 1738            Produtor de Jornalismo, Rádio e TV
# 1739                                      Pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                        Seção de Limpeza e Conservação
# 2                               Gabinete da Presidência
# 3     Seção de Segurança Interna, Perimetral e de Re...
# 4                       Seção de Controle do Patrimônio
# ...                                                 ...
# 1735                  Biblioteca Ministro Oscar Saraiva
# 1736     Seção de Digitalização de Petições e Processos
# 1737                    Coordenadoria de Relacionamento
# 1738                        Coordenadoria de TV e Rádio
# 1739          Coordenadoria de Engenharia e Arquitetura
#
# [1740 rows x 5 columns]
# definindo variável i_str
# 2023
# Entrando no looping do mês - variável j
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20230101.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2023-01
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20230101.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1                                      (XXX.810.461-XX)
# 2                                      (XXX.895.691-XX)
# 3                                      (XXX.906.901-XX)
# 4        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# ...                                                 ...
# 1734            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1735  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1736             Zaira Soares da Silva (XXX.584.961-XX)
# 1737              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1738          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1                            ALPHA TERCEIRIZAÇÃO EIRELI  05.456.176/0001-76
# 2                    VIPPIM SEGURANCA E VIGILANCIA LTDA  11.349.160/0001-67
# 3              G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 4               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# ...                                                 ...                 ...
# 1734           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1735  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1736                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1737            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1738                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                                         Servente
# 2                             Bombeiro Civil Líder
# 3                           Auxiliar de Biblioteca
# 4                          Técnico em Secretariado
# ...                                            ...
# 1734                        Auxiliar de Biblioteca
# 1735                                 Digitalizador
# 1736  Técnico Atendimento Suporte Presencial - ASP
# 1737            Produtor de Jornalismo, Rádio e TV
# 1738                                      Pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                        Seção de Limpeza e Conservação
# 2     Seção de Segurança Preventiva e Brigada de Inc...
# 3                     Biblioteca Ministro Oscar Saraiva
# 4                               Gabinete da Presidência
# ...                                                 ...
# 1734                  Biblioteca Ministro Oscar Saraiva
# 1735     Seção de Digitalização de Petições e Processos
# 1736                    Coordenadoria de Relacionamento
# 1737                        Coordenadoria de TV e Rádio
# 1738          Coordenadoria de Engenharia e Arquitetura
#
# [1739 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20230201.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2023-02
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20230201.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1                                      (XXX.810.461-XX)
# 2                                      (XXX.895.691-XX)
# 3                                      (XXX.906.901-XX)
# 4        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# ...                                                 ...
# 1712            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1713  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1714             Zaira Soares da Silva (XXX.584.961-XX)
# 1715              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1716          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1                            ALPHA TERCEIRIZAÇÃO EIRELI  05.456.176/0001-76
# 2                    VIPPIM SEGURANCA E VIGILANCIA LTDA  11.349.160/0001-67
# 3              G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 4               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# ...                                                 ...                 ...
# 1712           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1713  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1714                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1715            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1716                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                                         Servente
# 2                             Bombeiro Civil Líder
# 3                           Auxiliar de Biblioteca
# 4                          Técnico em Secretariado
# ...                                            ...
# 1712                        Auxiliar de Biblioteca
# 1713                                 Digitalizador
# 1714  Técnico Atendimento Suporte Presencial - ASP
# 1715            Produtor de Jornalismo, Rádio e TV
# 1716                                      Pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                        Seção de Limpeza e Conservação
# 2     Seção de Segurança Preventiva e Brigada de Inc...
# 3                     Biblioteca Ministro Oscar Saraiva
# 4                               Gabinete da Presidência
# ...                                                 ...
# 1712                  Biblioteca Ministro Oscar Saraiva
# 1713     Seção de Digitalização de Petições e Processos
# 1714                    Coordenadoria de Relacionamento
# 1715                        Coordenadoria de TV e Rádio
# 1716          Coordenadoria de Engenharia e Arquitetura
#
# [1717 rows x 5 columns]
# fazendo o teste do valor da variável j
# não se trata do mês atual. Definindo variável j_str
# testando se j é menor que 10
# definindo a variável string do codigo html
# 20230301.html
# definindo a chave do dicionário
# define a variável da endereco a ser acessado
# Iteração 2023-03
# Link: https://www.stj.jus.br/docs_internet/transparencia/stjtransparencia_anexoVI_20230301.html
#                                                       0
# 0                                     Nome do Empregado  \
# 1                                      (XXX.810.461-XX)
# 2                                      (XXX.895.691-XX)
# 3                                      (XXX.906.901-XX)
# 4        Abraão Jairo Bezerra da Silva (XXX.128.771-XX)
# ...                                                 ...
# 1718            Ylkiane Lopes da Silva (XXX.893.591-XX)
# 1719  Yvana Cristina de Freitas Amarante (XXX.653.60...
# 1720             Zaira Soares da Silva (XXX.584.961-XX)
# 1721              ZELIA SOUZA DE JESUS (XXX.963.711-XX)
# 1722          Zifirino Soares da Silva (XXX.671.607-XX)
#
#                                                       1                   2
# 0                                               Empresa                CNPJ  \
# 1                            ALPHA TERCEIRIZAÇÃO EIRELI  05.456.176/0001-76
# 2                    VIPPIM SEGURANCA E VIGILANCIA LTDA  11.349.160/0001-67
# 3              G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 4               BRASFORT ADMINISTRAÇÃO E SERVIÇOS LTDA.  36.770.857/0001-38
# ...                                                 ...                 ...
# 1718           G.S.I - SERVIÇOS ESPECIALIZADOS LTDA EPP  15.219.654/0001-88
# 1719  ASSOCIAÇÃO DE CENTRO DE TREINAMENTO DE EDUCAÇÃ...  26.444.653/0001-53
# 1720                         CONNECTCOM TELEINFORMATICA  00.308.141/0009-23
# 1721            PLANSUL PLANEJAMENTO E CONSULTORIA LTDA  78.533.312/0001-58
# 1722                                RCS TECNOLOGIA LTDA  08.220.952/0001-22
#
#                                                  3
# 0                                  Cargo/Atividade  \
# 1                                         Servente
# 2                             Bombeiro Civil Líder
# 3                           Auxiliar de Biblioteca
# 4                          Técnico em Secretariado
# ...                                            ...
# 1718                        Auxiliar de Biblioteca
# 1719                                 Digitalizador
# 1720  Técnico Atendimento Suporte Presencial - ASP
# 1721            Produtor de Jornalismo, Rádio e TV
# 1722                                      Pedreiro
#
#                                                       4
# 0                          Lotação / Local de Exercício
# 1                        Seção de Limpeza e Conservação
# 2     Seção de Segurança Preventiva e Brigada de Inc...
# 3                     Biblioteca Ministro Oscar Saraiva
# 4                               Gabinete da Presidência
# ...                                                 ...
# 1718                  Biblioteca Ministro Oscar Saraiva
# 1719     Seção de Digitalização de Petições e Processos
# 1720                    Coordenadoria de Relacionamento
# 1721                        Coordenadoria de TV e Rádio
# 1722          Coordenadoria de Engenharia e Arquitetura
#
# [1723 rows x 5 columns]
# fazendo o teste do valor da variável j

# %%
#Constrói um dicionário de informações extraídas das tabelas de terceirizados
df_informacoes_terceirizados = {}

#Compila valores do dicionário de dataframes obtido
for item in dfs_terceirizados:
    print(item)
    display(dfs_terceirizados[item])
    df_unidades_limpeza = filtra_dataframe(dfs_terceirizados[item], 4 , ["Seção de Limpeza e Conservação","Coordenadoria de Conservação Predial","Seção de Administração de Edifícios"])
    df_terceirizados_limpeza = filtra_dataframe(df_unidades_limpeza, 3, ["Jauzeiro", "Servente", "Supervisor", "Supervisor Geral de Serventes"])
    display(df_terceirizados_limpeza)
    terceirizados_limpeza = conta_quantidade_terceirizados(df_terceirizados_limpeza)
    terceirizados_total = conta_quantidade_terceirizados(dfs_terceirizados[item]) - 1
    
    df_informacoes_terceirizados[item] = (terceirizados_total, terceirizados_limpeza)

# %%
#Obtém lista de datas a serem atualizadas
datas_update = [data for data in df_informacoes_terceirizados if len(df_atual.loc[df_atual['data'] == data]) > 0]

#Obtém lista de datas a serem acrescentadas
datas_add = [data for data in df_informacoes_terceirizados if len(df_atual.loc[df_atual['data'] == data]) == 0]

#Atualiza os valores do dataframe com os valores retornados pela consulta atual
for data in datas_update:
    df_atual.loc[df_atual['data'] == data] = [data, df_informacoes_terceirizados[data][0], df_informacoes_terceirizados[data][1]]

#Acrescenta os novos valores obtidos pela consulta no dataframe
for data in datas_add:
    new_row = {'data': [data], 'terceirizados': [df_informacoes_terceirizados[data][0]], 'terceirizados_limpeza': [df_informacoes_terceirizados[data][1]]}
    df_atual = pd.concat([df_atual, pd.DataFrame(new_row)], ignore_index = True)

for data in datas_update:
    display(df_atual.loc[df_atual['data'] == data])

    
for data in datas_add:
    display(df_atual.loc[df_atual['data'] == data])
# Out:
#           data terceirizados  terceirizados_limpeza
# 102 2022-07-01          1733                    148
#           data terceirizados  terceirizados_limpeza
# 103 2022-08-01          1706                    148
#           data terceirizados  terceirizados_limpeza
# 104 2022-09-01          1724                    147
#           data terceirizados  terceirizados_limpeza
# 105 2022-10-01          1738                    148
#           data terceirizados  terceirizados_limpeza
# 106 2022-11-01          1738                    147
#           data terceirizados  terceirizados_limpeza
# 107 2022-12-01          1739                    147
#           data terceirizados  terceirizados_limpeza
# 108 2023-01-01          1738                    148
#           data terceirizados  terceirizados_limpeza
# 109 2023-02-01          1716                    148
#           data terceirizados  terceirizados_limpeza
# 110 2023-03-01          1722                    148

# %%
#Dataframe final
display(df_atual)

#Exporta o dataframe final
df_atual.to_csv('QtdTerceirizados.csv', index = False)
# Out:
#           data terceirizados  terceirizados_limpeza
# 0   2014-01-01          1597                    175
# 1   2014-02-01          1597                    175
# 2   2014-03-01          1592                    171
# 3   2014-04-01          1583                    171
# 4   2014-05-01          1582                    168
# ..         ...           ...                    ...
# 106 2022-11-01          1738                    147
# 107 2022-12-01          1739                    147
# 108 2023-01-01          1738                    148
# 109 2023-02-01          1716                    148
# 110 2023-03-01          1722                    148
#
# [111 rows x 3 columns]
